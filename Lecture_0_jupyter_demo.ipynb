# %% [markdown]
# # Вступ
# Мене **звати** Степан!
#
# Я пишу код на *Python*!
#
# Ця програма робить щось корисне.

# %% [markdown]
# Here is numerated list
# 1. First Block
# 2. Second block
# 3. Third block
#     - Sublist
#     - Sublist 2
#     - Sublist 3

# %%
print('Hello world!')
# Out:
# Hello world!

# %%
# !ls
# Out:
# 1538.88s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Lecture_0_jupyter_demo.ipynb test.ipynb
# README.md

# %%
120+20
# Out:
# 140

# %% [markdown]
# ## Розділ 1
# просто текст
#
# ### Підрозділ
#
# #### Підрозділ 2
#
# ## Розділ 2

# %%
import time

for i in range(4):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
my_list = [1, 2, 3, 4]

# %%
my_list
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# В мене є список
# * Один
#     - підсписок
#         - це
#   - інший підписок
#         - то
#         - і ще то
# * два
#   - підсписок

# %%
[x**2 for x in range(-10, 20)]
# Out:
# [100,
#  81,
#  64,
#  49,
#  36,
#  25,
#  16,
#  9,
#  4,
#  1,
#  0,
#  1,
#  4,
#  9,
#  16,
#  25,
#  36,
#  49,
#  64,
#  81,
#  100,
#  121,
#  144,
#  169,
#  196,
#  225,
#  256,
#  289,
#  324,
#  361]

# %%
s = 'Hello world!'

# %%
print(s)
# Out:
# Hello world!

# %%
1+1
print(2+22)
3+3
s
# Out:
# 24
# 'Hello world!'

# %%
a = 'Hello everyone!'

# %%
a
# Out:
# 'Hello everyone!'

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(np.cos(range(40)))

# %% [markdown]
# ## Розділ 3

# %%
a = 1
b = 2
a + b
# Out:
# 3

# %%
a / b
# Out:
# 0.5
